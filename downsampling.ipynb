# %%
import os

# %%
path=os.getcwd()

# %%
os.chdir("normal")

# %%
path
# Out:
# 'D:\\ecg-classifier-semster5\\ecg-identifier\\ecg-images\\ML\\train\\normal'

# %%
photos=os.listdir(path)

# %%
len(photos)
# Out:
# 45035

# %%
photos
# Out:
# ['101_1.png',
#  '101_10.png',
#  '101_100.png',
#  '101_1000.png',
#  '101_1001.png',
#  '101_1002.png',
#  '101_1003.png',
#  '101_1004.png',
#  '101_1005.png',
#  '101_1006.png',
#  '101_1007.png',
#  '101_1008.png',
#  '101_1009.png',
#  '101_101.png',
#  '101_1010.png',
#  '101_1011.png',
#  '101_1012.png',
#  '101_1013.png',
#  '101_1014.png',
#  '101_1015.png',
#  '101_1016.png',
#  '101_1017.png',
#  '101_1018.png',
#  '101_1019.png',
#  '101_102.png',
#  '101_1020.png',
#  '101_1021.png',
#  '101_1022.png',
#  '101_1023.png',
#  '101_1024.png',
#  '101_1025.png',
#  '101_1026.png',
#  '101_1027.png',
#  '101_1028.png',
#  '101_1029.png',
#  '101_103.png',
#  '101_1030.png',
#  '101_1031.png',
#  '101_1032.png',
#  '101_1033.png',
#  '101_1034.png',
#  '101_1035.png',
#  '101_1036.png',
#  '101_1037.png',
#  '101_1038.png',
#  '101_1039.png',
#  '101_104.png',
#  '101_1040.png',
#  '101_1041.png',
#  '101_1042.png',
#  '101_1043.png',
#  '101_1044.png',
#  '101_1045.png',
# ...

# %%
photos_copy=photos[:]

# %%
# Out:
# ['101_1.png',
#  '101_10.png',
#  '101_100.png',
#  '101_1000.png',
#  '101_1001.png',
#  '101_1002.png',
#  '101_1003.png',
#  '101_1004.png',
#  '101_1005.png',
#  '101_1006.png',
#  '101_1007.png',
#  '101_1008.png',
#  '101_1009.png',
#  '101_101.png',
#  '101_1010.png',
#  '101_1011.png',
#  '101_1012.png',
#  '101_1013.png',
#  '101_1014.png',
#  '101_1015.png',
#  '101_1016.png',
#  '101_1017.png',
#  '101_1018.png',
#  '101_1019.png',
#  '101_102.png',
#  '101_1020.png',
#  '101_1021.png',
#  '101_1022.png',
#  '101_1023.png',
#  '101_1024.png',
#  '101_1025.png',
#  '101_1026.png',
#  '101_1027.png',
#  '101_1028.png',
#  '101_1029.png',
#  '101_103.png',
#  '101_1030.png',
#  '101_1031.png',
#  '101_1032.png',
#  '101_1033.png',
#  '101_1034.png',
#  '101_1035.png',
#  '101_1036.png',
#  '101_1037.png',
#  '101_1038.png',
#  '101_1039.png',
#  '101_104.png',
#  '101_1040.png',
#  '101_1041.png',
#  '101_1042.png',
#  '101_1043.png',
#  '101_1044.png',
#  '101_1045.png',
# ...

# %%
import numpy as np

# %%
arr=np.random.randint(45000, size=27000)

# %%
len(arr)
# Out:
# 27000

# %%
unique_arr=list(set(arr))

# %%
len(unique_arr)
# Out:
# 20318

# %%
path=os.getcwd()

# %%
path
# Out:
# 'D:\\ecg-classifier-semster5\\ecg-identifier\\ecg-images\\ML\\train\\normal'

# %%
for x in
